# %% [markdown]
# # Mount Pinatubo

# %% [markdown]
# ### Import Necessary Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import pytz
sns.set(style="darkgrid")

# %% [markdown]
# ### Read in Data

# %%
df = pd.read_csv('EarthquakeData.csv')
df.head()
# Out:
#                        time  latitude  longitude   depth  mag magType  nst  \
# 0  2019-04-26T23:20:43.982Z   15.5760   119.3247   10.00  4.6      mb  NaN
# 1  2019-04-26T23:14:09.859Z   15.5718   119.1792   10.00  4.4      mb  NaN
# 2  2019-04-23T18:02:59.987Z   14.9108   120.5743   53.44  4.7      mb  NaN
# 3  2019-04-22T15:38:40.496Z   13.7277   120.9237  142.31  4.3      mb  NaN
# 4  2019-04-22T09:11:11.751Z   14.9566   120.5121   20.00  6.1     mww  NaN
#
#      gap    dmin   rms  ...                   updated  \
# 0  102.0   7.391  0.71  ...  2019-04-27T00:13:43.040Z
# 1  100.0   9.905  0.59  ...  2019-05-10T23:15:56.040Z
# 2  118.0   7.879  0.75  ...  2019-04-24T16:10:44.505Z
# 3  145.0  14.129  0.46  ...  2019-05-05T15:26:59.040Z
# 4   20.0   0.943  1.04  ...  2019-05-22T13:15:42.040Z
#
#                                 place        type horizontalError depthError  \
# 0    61km WSW of Bolitoc, Philippines  earthquake             9.8        1.9
# 1    76km SW of Ilioilio, Philippines  earthquake            11.0        1.8
# 2  1km ESE of Santa Cruz, Philippines  earthquake             9.1        7.5
# 3       1km SW of Talaga, Philippines  earthquake            21.9       11.6
# 4       0km ESE of Gutad, Philippines  earthquake             5.9        1.8
#
#    magError  magNst    status  locationSource magSource
# 0     0.053   106.0  reviewed              us        us
# 1     0.066    67.0  reviewed              us        us
# 2     0.046   144.0  reviewed              us        us
# 3     0.169    10.0  reviewed              us        us
# 4     0.035    77.0  reviewed              us        us
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Preliminary Data Analysis

# %%
print(list(df.columns))
# Out:
# ['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst', 'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type', 'horizontalError', 'depthError', 'magError', 'magNst', 'status', 'locationSource', 'magSource']

# %%
df = df.loc[:,:'place']
df.drop(columns = ['nst','gap','dmin','rms','net','id','updated','magType'],inplace=True)
df.head()
# Out:
#                        time  latitude  longitude   depth  mag  \
# 0  2019-04-26T23:20:43.982Z   15.5760   119.3247   10.00  4.6
# 1  2019-04-26T23:14:09.859Z   15.5718   119.1792   10.00  4.4
# 2  2019-04-23T18:02:59.987Z   14.9108   120.5743   53.44  4.7
# 3  2019-04-22T15:38:40.496Z   13.7277   120.9237  142.31  4.3
# 4  2019-04-22T09:11:11.751Z   14.9566   120.5121   20.00  6.1
#
#                                 place
# 0    61km WSW of Bolitoc, Philippines
# 1    76km SW of Ilioilio, Philippines
# 2  1km ESE of Santa Cruz, Philippines
# 3       1km SW of Talaga, Philippines
# 4       0km ESE of Gutad, Philippines

# %%
df['time'] = pd.to_datetime(df['time'],utc = False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1970 entries, 0 to 1969
# Data columns (total 6 columns):
# time         1970 non-null datetime64[ns, UTC]
# latitude     1970 non-null float64
# longitude    1970 non-null float64
# depth        1970 non-null float64
# mag          1837 non-null float64
# place        1970 non-null object
# dtypes: datetime64[ns, UTC](1), float64(4), object(1)
# memory usage: 92.4+ KB

# %%
#View Earthquakes
plt.scatter(df['time'],df['mag'])
plt.title('Earthquakes around Mt Pinatubo')
plt.xlabel('Date')
plt.ylabel('Magnitude')
# Out:
# Text(0, 0.5, 'Magnitude')

# %%
#Remove magnitude 0 earthquakes from data
df = df.query('mag > 0')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1778 entries, 0 to 1969
# Data columns (total 6 columns):
# time         1778 non-null datetime64[ns, UTC]
# latitude     1778 non-null float64
# longitude    1778 non-null float64
# depth        1778 non-null float64
# mag          1778 non-null float64
# place        1778 non-null object
# dtypes: datetime64[ns, UTC](1), float64(4), object(1)
# memory usage: 97.2+ KB

# %%
#Check if there is a pattern of big earthquakes
dfbig = df.query('mag > 6')

#sns.set(style="whitegrid")
plt.scatter(dfbig['time'],dfbig['mag'])
plt.title('Earthquakes around Mt Pinatubo')
plt.xlabel('Date')
plt.ylabel('Magnitude')
# Out:
# Text(0, 0.5, 'Magnitude')

# %%
#Replot without magnitude 0 earthquakes
#sns.set(style="whitegrid")
plt.scatter(df['time'],df['mag'],s = 5)
plt.title('Earthquakes around Mt Pinatubo')
plt.xlabel('Date')
plt.ylabel('Magnitude')
# Out:
# Text(0, 0.5, 'Magnitude')

# %%
#Allow for query by time - note must reconcile universal versus local time
df.set_index('time')

#Prior two years
dt1 = dt.datetime(1989, 6, 20, 0, 0, 0, 0, pytz.UTC)
print(dt1)
dt2 = dt.datetime(1991, 6, 20, 0, 0, 0, 0, pytz.UTC)


df1991 = df.loc[(df['time'] > dt1) & (df['time'] < dt2)]

len(df1991)
#df1991 = df.loc[df['time'].dt.year == 1991]
plt.scatter(df1991['time'],df1991['mag'],s=15)
plt.title('Earthquakes around Mt Pinatubo')
plt.xlabel('Date')
plt.ylabel('Magnitude')
plt.xticks(rotation=45)
# Out:
# 1989-06-20 00:00:00+00:00
# (array([726284., 726376., 726468., 726558., 726649., 726741., 726833.,
#         726923., 727014.]), <a list of 9 Text xticklabel objects>)

# %%
#Prior month
dt1 = dt.datetime(1991, 1, 1, 0, 0, 0, 0, pytz.UTC)
print(dt1)
dt2 = dt.datetime(1991, 6, 25, 0, 0, 0, 0, pytz.UTC)

df1991 = df.loc[(df['time'] > dt1) & (df['time'] < dt2)]

df1991.head(10)
#df1991 = df.loc[df['time'].dt.year == 1991]
# Out:
# 1991-01-01 00:00:00+00:00
#                                  time  latitude  longitude  depth  mag  \
# 1311 1991-06-24 19:48:08.020000+00:00    14.961    120.443   10.0  4.9
# 1312 1991-06-24 16:01:52.550000+00:00    14.646    120.293   53.8  4.6
# 1313 1991-06-21 14:43:08.170000+00:00    15.277    120.362   10.0  4.7
# 1314 1991-06-20 09:12:48.330000+00:00    15.087    120.241   10.0  4.8
# 1315 1991-06-19 03:06:42.850000+00:00    15.001    120.034   10.0  4.4
# 1316 1991-06-18 20:17:48.520000+00:00    15.231    120.293   10.0  4.8
# 1317 1991-06-18 03:20:25.310000+00:00    15.219    120.322   10.0  4.9
# 1318 1991-06-17 23:10:02.850000+00:00    15.203    120.393   10.0  4.2
# 1319 1991-06-17 17:14:42.380000+00:00    15.615    120.479   10.0  4.4
# 1320 1991-06-17 16:37:52.820000+00:00    15.193    120.250   10.0  4.6
#
#                    place
# 1311  Luzon, Philippines
# 1312  Luzon, Philippines
# 1313  Luzon, Philippines
# 1314  Luzon, Philippines
# 1315  Luzon, Philippines
# 1316  Luzon, Philippines
# 1317  Luzon, Philippines
# 1318  Luzon, Philippines
# 1319  Luzon, Philippines
# 1320  Luzon, Philippines

# %%
plt.scatter(df1991['time'],df1991['mag'])
plt.title('Earthquakes around Mt Pinatubo')
plt.xlabel('Date')
plt.ylabel('Magnitude')
plt.xticks(rotation=45)
# Out:
# (array([726833., 726864., 726892., 726923., 726953., 726984., 727014.]),
#  <a list of 7 Text xticklabel objects>)

# %% [markdown]
# # Volcanic Forcing Data Analysis

# %% [markdown]
# DESCRIPTION OF DATA:
# Monthly volcanic forcing data for climate modeling from 1890-1999.
# Aerosol from each event is individually evolved spatially at monthly
# resolution.  Latitude bands are 2.8 degrees. The peak aerosol optical
# depth for each eruption is scaled from estimates of peak aerosol
# loading [Stothers 1996; Hofmann and Rosen 1983; Stenchikov
# et al., 1998] assuming spherical sulfuric acid droplets
# with a composition of 75% H2SO4 and 25% H2O and a
# fixed aerosol size distribution (using reff = 0.42 micron
# [Ammann et al., 2003], a mid-sized aerosol comparable to
# an average Pinatubo aerosol, Stenchikov et al. [1998]; see
# also Stothers [2001b] for estimates of reff for individual
# events). Using the month of the eruption and an estimated
# peak amount of sulfate aerosol reached through linear
# buildup after 4 months, aerosol from tropical eruptions is
# transported in the lower stratosphere from the tropics
# (25N�25S) into the midlatitudes of the respective winter
# hemisphere, where it subsequently decays during the summer
# season. Over the poles, aerosol is rapidly removed
# during winter, but is advected from midlatitudes in spring
# and summer after the breakdown of the polar vortex. The
# e-folding time for decay is set to 12 months in the tropics.
# The aerosol from high-latitude eruptions is restricted to
# remain poleward of 30 degrees of the appropriate hemisphere.

# %%
df1 = pd.read_csv('VolcanicForcing.csv')
df1.head()
# Out:
#         2.8       5.6       8.4      11.2        14      16.8      19.6  \
# 0  0.003435  0.003435  0.003435  0.003435  0.003435  0.003435  0.003435
# 1  0.003161  0.003161  0.003161  0.003161  0.003161  0.003161  0.003161
# 2  0.002676  0.002676  0.002676  0.002676  0.002676  0.002809  0.002908
# 3  0.002265  0.002265  0.002265  0.002265  0.002265  0.015278  0.025000
# 4  0.001917  0.001917  0.001917  0.001917  0.001917  0.029438  0.050000
#
#        22.4      25.2        28  ...       154     156.8     159.6     162.4  \
# 0  0.003435  0.003435  0.003435  ...  0.003435  0.003435  0.003435  0.003435
# 1  0.003161  0.003161  0.003161  ...  0.003161  0.003161  0.003161  0.003161
# 2  0.002908  0.002908  0.002908  ...  0.002908  0.002908  0.002908  0.002908
# 3  0.025000  0.025000  0.025000  ...  0.002676  0.002676  0.002676  0.002676
# 4  0.050000  0.050000  0.050000  ...  0.002462  0.002462  0.002462  0.002462
#
#       165.2       168     170.8     173.6     176.4     179.2
# 0  0.002935  0.002265  0.002265  0.002265  0.002265  0.002265
# 1  0.002629  0.001917  0.001917  0.001917  0.001917  0.001917
# 2  0.002358  0.001623  0.001623  0.001623  0.001623  0.001623
# 3  0.002676  0.002676  0.002676  0.002676  0.002676  0.002676
# 4  0.002462  0.002462  0.002462  0.002462  0.002462  0.002462
#
# [5 rows x 64 columns]

# %%
#Clean data
df1['year'] = df1.index/12 + 1890
df1['year'] = df1['year'].astype(int)
df1['month'] = df1.index % 12 + 1

#df1['date'] = str(df1['year'])+ str(df1['month'])
df1['date'] = pd.to_datetime(df1['year'].astype(str) + df1['month'].astype(str), format='%Y%m')

df1['total'] = df1.loc[:, '2.8':'179.2'].sum(1)

df1.head(10)
# Out:
#         2.8       5.6       8.4      11.2        14      16.8      19.6  \
# 0  0.003435  0.003435  0.003435  0.003435  0.003435  0.003435  0.003435
# 1  0.003161  0.003161  0.003161  0.003161  0.003161  0.003161  0.003161
# 2  0.002676  0.002676  0.002676  0.002676  0.002676  0.002809  0.002908
# 3  0.002265  0.002265  0.002265  0.002265  0.002265  0.015278  0.025000
# 4  0.001917  0.001917  0.001917  0.001917  0.001917  0.029438  0.050000
# 5  0.001623  0.001623  0.001623  0.001623  0.001623  0.043622  0.075000
# 6  0.001374  0.001374  0.001374  0.001374  0.001374  0.057824  0.100000
# 7  0.001163  0.001163  0.001163  0.001163  0.001163  0.072043  0.125000
# 8  0.000984  0.000984  0.000984  0.000984  0.000984  0.071967  0.125000
# 9  0.112500  0.112500  0.112500  0.112500  0.112500  0.112500  0.112500
#
#        22.4      25.2        28  ...     165.2       168     170.8     173.6  \
# 0  0.003435  0.003435  0.003435  ...  0.002935  0.002265  0.002265  0.002265
# 1  0.003161  0.003161  0.003161  ...  0.002629  0.001917  0.001917  0.001917
# 2  0.002908  0.002908  0.002908  ...  0.002358  0.001623  0.001623  0.001623
# 3  0.025000  0.025000  0.025000  ...  0.002676  0.002676  0.002676  0.002676
# 4  0.050000  0.050000  0.050000  ...  0.002462  0.002462  0.002462  0.002462
# 5  0.075000  0.075000  0.075000  ...  0.002265  0.002265  0.002265  0.002265
# 6  0.100000  0.100000  0.100000  ...  0.002084  0.002084  0.002084  0.002084
# 7  0.125000  0.125000  0.125000  ...  0.001917  0.001917  0.001917  0.001917
# 8  0.125000  0.125000  0.125000  ...  0.001704  0.001623  0.001623  0.001623
# 9  0.112500  0.112500  0.112500  ...  0.014897  0.001374  0.001374  0.001374
#
#       176.4     179.2  year  month       date     total
# 0  0.002265  0.002265  1890      1 1890-01-01  0.158478
# 1  0.001917  0.001917  1890      2 1890-02-01  0.144922
# 2  0.001623  0.001623  1890      3 1890-03-01  0.792486
# 3  0.002676  0.002676  1890      4 1890-04-01  1.819655
# 4  0.002462  0.002462  1890      5 1890-05-01  3.013800
# 5  0.002265  0.002265  1890      6 1890-06-01  4.112415
# 6  0.002084  0.002084  1890      7 1890-07-01  4.790981
# 7  0.001917  0.001917  1890      8 1890-08-01  4.870673
# 8  0.001623  0.001623  1890      9 1890-09-01  4.620313
# 9  0.001374  0.001374  1890     10 1890-10-01  5.112548
#
# [10 rows x 68 columns]

# %%
rand = df1.query('year >1990 and year < 1995')

# %%
plt.plot(df1['date'],df1['total'])
plt.title('Global Volcanic Forcing')
plt.xlabel('Date')
plt.ylabel('Total Aerosol Optical Thickness')
plt.xticks(rotation=45)
# Out:
# (array([686291., 693596., 700900., 708205., 715510., 722815., 730120.,
#         737425.]), <a list of 8 Text xticklabel objects>)

# %%
plt.plot(rand['date'],rand['total'])
plt.xticks(rotation = 90)
plt.title('Volcanic Forcing of Mt Pinatubo')
plt.xlabel('Date')
plt.ylabel('Total Aerosol Optical Thickness')
plt.xticks(rotation=45)
# Out:
# (array([726833., 727014., 727198., 727380., 727564., 727745., 727929.,
#         728110., 728294.]), <a list of 9 Text xticklabel objects>)

# %%
rand1 = df1.query('year > 1990 and year < 1993')
plt.plot(rand1['date'],rand1['total'])
plt.title('Volcanic Forcing of Mt Pinatubo')
plt.xlabel('Date')
plt.ylabel('Optical Thickness')
plt.xticks(rotation = 45)
# Out:
# (array([726833., 726923., 727014., 727106., 727198., 727289., 727380.,
#         727472., 727564.]), <a list of 9 Text xticklabel objects>)

# %%
plt.figure(1)
plt.plot(rand['date'],rand['106.4'],label='Mount Pinatubo')
plt.plot(rand['date'],rand['179.2'],label='North Pole')
plt.plot(rand['date'],rand['2.8'],label='South Pole')
plt.title('Volcanic Forcing of Mt Pinatubo')
plt.xlabel('Date')
plt.ylabel('Aerosol Optical Thickness')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
plt.figure(1)
plt.plot(rand['date'],rand['106.4'],label = 'Mt Pinatubo')
#plt.plot(rand['date'],rand['120.4'])
plt.plot(rand['date'],rand['148.4'],label = '+42 degrees lat')
#plt.plot(rand['date'],rand['134.4'])
#plt.plot(rand['date'],rand['92.4'])
#plt.plot(rand['date'],rand['78.4'])
plt.plot(rand['date'],rand['64.4'],label = '-42 degrees lat')
plt.title('Volcanic Forcing of Mt Pinatubo')
plt.xlabel('Date')
plt.ylabel('Aerosol Optical Thickness')
plt.xticks(rotation = 45)
plt.legend()
plt.show()

# %%
dt1 = dt.datetime(1991, 5, 1)
print(dt1)
dt2 = dt.datetime(1992, 12, 1)

rand2 = df1.loc[(df1['date'] > dt1) & (df1['date'] < dt2)]
#rand2 = df1.query('date == 1991-06-01')
plt.figure(1)
plt.plot(rand2['date'],rand2['106.4'])
#plt.plot(rand2['date'],rand2['120.4'])
plt.plot(rand2['date'],rand2['134.4'])
#plt.plot(rand2['date'],rand2['92.4'])
plt.plot(rand2['date'],rand2['78.4'])
plt.title('Volcanic Forcing of Mt Pinatubo')
plt.xlabel('Date')
plt.ylabel('Optical Thickness')
plt.legend()
# plt.plot(rand2['date'],rand2['151.2'])
# plt.plot(rand2['date'],rand2['39.2'])
plt.xticks(rotation = 45)
plt.show()
# Out:
# 1991-05-01 00:00:00

# %% [markdown]
# # Eruption History Dataset

# %%
df2 = pd.read_csv('EruptionHist.csv')
df2.head()
# Out:
#       volcano     lat      lon  v_alt    yyyy    mm   dd type  vei  p_alt_obs  \
# 0      Ambrym  -16.25  168.120  1.334  1978.0  12.0  5.0  exp  2.0     -999.0
# 1  Cerro_Azul   -0.92  -91.408  1.690  1979.0   2.0  1.0  eff  2.0        2.0
# 2  Cerro_Azul   -0.92  -91.408  1.690  1979.0   2.0  2.0  eff  2.0        7.0
# 3  Cerro_Azul   -0.92  -91.408  1.690  1979.0   2.0  3.0  eff  2.0        2.0
# 4  Cerro_Azul   -0.92  -91.408  1.690  1979.0   2.0  4.0  eff  2.0        3.0
#
#    p_alt_est   so2
# 0     11.334  87.0
# 1   -999.000  10.0
# 2   -999.000  60.0
# 3   -999.000  40.0
# 4   -999.000  10.0

# %%
plt.scatter(df2['yyyy'],df2['so2'])
# Annotate with text + Arrow
plt.annotate('Mount Pinatubo Eruption!', xy=(1991, 14900), xytext=(2000, 11000),
arrowprops=dict(facecolor='black', shrink=0.05)
)
plt.title('Sulfur Dioxide Output by Volcanic Eruption')
plt.xlabel('Date')
plt.ylabel('Sulfur Dioxide (SO2)')
# Out:
# Text(0, 0.5, 'Sulfur Dioxide (SO2)')

# %%
print(list(df1.columns))
# Out:
# ['2.8', '5.6', '8.4', '11.2', '14', '16.8', '19.6', '22.4', '25.2', '28', '30.8', '33.6', '36.4', '39.2', '42', '44.8', '47.6', '50.4', '53.2', '56', '58.8', '61.6', '64.4', '67.2', '70', '72.8', '75.6', '78.4', '81.2', '84', '86.8', '89.6', '92.4', '95.2', '98', '100.8', '103.6', '106.4', '109.2', '112', '114.8', '117.6', '120.4', '123.2', '126', '128.8', '131.6', '134.4', '137.2', '140', '142.8', '145.6', '148.4', '151.2', '154', '156.8', '159.6', '162.4', '165.2', '168', '170.8', '173.6', '176.4', '179.2', 'year', 'month', 'date', 'total']
